# %%
import numpy as np
from PIL import Image
import glob
import re

# %%
IMGS_DIR = "character_imgs/ascii/CascadiaMono/"

# %%
img = Image.open(IMGS_DIR + "100.bmp")
img_arr = np.array(img)

img_size = img_arr.size
img_shape = img_arr.shape

print(img_size, img_shape)
print(np.split(img_arr, 2)[0].shape)
img
# Out:
# 288 (24, 12)
# (12, 12)
# <PIL.BmpImagePlugin.BmpImageFile image mode=1 size=12x24>

# %%
img_ls = glob.glob(IMGS_DIR + "*.bmp")
char_ls = []
for i in range(0, len(img_ls)):
    img = Image.open(img_ls[i])
    img = np.array(img)
    img_top_bottom = np.split(img, 2)
    char_ls.append((chr(int(re.findall(r'\d+', img_ls[i])[0])),
                img.size // 2 - np.count_nonzero(img_top_bottom[0]),
                img.size // 2 - np.count_nonzero(img_top_bottom[1])))

# %%
char_ls.sort(key=lambda a: (a[1], a[2]))

# %%
brightness_str = [c[0] for c in char_ls]

print(brightness_str)
# Out:
# [' ', '.', ',', '_', ':', ';', '`', '-', "'", 'y', '~', 'v', '!', 'x', 'L', 'a', 'u', 'e', '<', 'o', 'c', 's', '+', '>', '\\', 'n', 'z', '/', 'w', 'p', '|', '=', '1', 'J', 'q', 'g', 'l', 'r', 'k', ')', 'i', 'j', 'm', '"', '^', '*', '(', '{', '3', 't', '}', 'I', '[', ']', '4', 'A', 'G', 'C', 'X', '2', '&', '?', 'Y', 'F', 'V', 'h', 'b', 'U', 'S', 'Z', 'T', '%', 'd', 'f', '6', 'E', 'H', 'O', 'Q', 'P', '8', 'K', '0', 'D', '7', '5', '#', 'B', 'W', '9', '@', 'R', 'N', 'M', '$']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))
top_brightness = [a[1] for a in char_ls]
bottom_brightness = [a[2] for a in char_ls]
plt.scatter(bottom_brightness, top_brightness, marker='.')
plt.xticks(np.arange(min(bottom_brightness), max(bottom_brightness), 5))
plt.yticks(np.arange(min(top_brightness), max(top_brightness), 5))
plt.xlabel("bottom_brightness")
plt.ylabel("top_brightness")
for i in range(len(char_ls)):
    plt.annotate(brightness_str[i], (bottom_brightness[i], top_brightness[i]), size=20)
plt.grid()

# %%
y_dim = 10
x_dim = 10
brightness_arr = [[''] * x_dim for _ in range(y_dim)]

n_top_brightness = list(map(lambda b: b / max(top_brightness), top_brightness))
n_bottom_brightness = list(map(lambda b: b / max(bottom_brightness), bottom_brightness))

char_to_n_bt_brightness = {}
for b in zip(brightness_str, n_top_brightness, n_bottom_brightness):
    char_to_n_bt_brightness[b[0]] = (b[1], b[2], (b[1] + b[2]) / 2)

for c, b in char_to_n_bt_brightness.items():
    brightness_arr[int(b[0] * (y_dim - 1))][int(b[1] * (x_dim - 1))] += c

for row in brightness_arr:
    print(row)
# Out:
# [' ', '.', ',', '_', '', '', '', '', '', '']
# ['', ':', ';', '', '', '', '', '', '', '']
# ["`'", '-!', '~', '', 'vxL', '', '', 'ya', '', '']
# ['', '', '<+>', '\\/', 'cn', 'osz', 'uew', 'p', '', '']
# ['', '', '', '|=l)', '1Jrij', 'k', 'm', 'q', '', 'g']
# ['"^', '*', '?Y', '(tF', '{3}I[]CXVh', '4A2bU', '', 'G&', '', '']
# ['', '', 'T', 'f', 'SZ', '%d6EHO', '', 'Q', '', '']
# ['', '', '7', '', 'P5', '#9', '8K0DB', 'W@', '', '']
# ['', '', '', 'M', '', '', 'RN', '', '', '']
# ['', '', '', '', '', '', '', '$', '', '']

# %%
def splice_cell(top, left):
    res = top[0]
    for a in top:
        if (char_to_n_bt_brightness[res][2] < char_to_n_bt_brightness[a][2]):
            res = a

    for a in left:
        if (char_to_n_bt_brightness[res][2] < char_to_n_bt_brightness[a][2]):
            res = a
    return res


for y in range(y_dim):
    for x in range(x_dim):
        if brightness_arr[y][x] == '':
            if x > 0 and y > 0:
                brightness_arr[y][x] += splice_cell(brightness_arr[y-1][x], brightness_arr[y][x-1])
            elif x > 0:
                brightness_arr[y][x] += brightness_arr[y][x - 1][-1]
            elif y > 0:
                brightness_arr[y][x] += brightness_arr[y - 1][x][-1]
            brightness_arr[y][x] = ''.join(set(brightness_arr[y][x]))

for row in brightness_arr:
    print(row)
# Out:
# [' ', '.', ',', '_', '_', '_', '_', '_', '_', '_']
# [' ', ':', ';', ';', ';', ';', ';', ';', ';', ';']
# ["`'", '-!', '~', '~', 'vxL', 'x', 'x', 'ya', 'a', 'a']
# ["'", '!', '<+>', '\\/', 'cn', 'osz', 'uew', 'p', 'p', 'p']
# ["'", '!', '+', '|=l)', '1Jrij', 'k', 'm', 'q', 'q', 'g']
# ['"^', '*', '?Y', '(tF', '{3}I[]CXVh', '4A2bU', 'm', 'G&', '&', '&']
# ['^', '*', 'T', 'f', 'SZ', '%d6EHO', 'O', 'Q', 'Q', 'Q']
# ['^', '*', '7', '7', 'P5', '#9', '8K0DB', 'W@', '@', '@']
# ['^', '*', '7', 'M', '5', '#', 'RN', '@', '@', '@']
# ['^', '*', '7', 'M', '5', '#', 'N', '$', '$', '$']

# %%
for y in range(y_dim):
    for x in range(x_dim):
        num_chars = len(brightness_arr[y][x])
        if num_chars > 1:
            brightness_arr[y][x] = brightness_arr[y][x][num_chars // 2 - 1]

b_set = set()
for row in brightness_arr:
    b_set = b_set.union(set(row))
    print(' '.join(row))

print(len(b_set))
# Out:
#   . , _ _ _ _ _ _ _
#   : ; ; ; ; ; ; ; ;
# ` - ~ ~ v x x y a a
# ' ! < \ c o u p p p
# ' ! + = J k m q q g
# " * ? ( [ A m G & &
# ^ * T f S 6 O Q Q Q
# ^ * 7 7 P # K W @ @
# ^ * 7 M 5 # R @ @ @
# ^ * 7 M 5 # N $ $ $
# 54
