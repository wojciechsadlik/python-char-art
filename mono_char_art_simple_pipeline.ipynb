# %%
from PIL import Image, ImageOps, ImageFont
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets
from ipywidgets import interactive, HBox, VBox
from ansi_colorizer import AnsiColorizer, reset_code
from mono_char_art_conversion_1x1 import img2char_arr_1x1
from mono_char_art_conversion_1x2 import img2char_arr_1x2
from img_processing import preprocess_img, DITHER_MODES
from braille_art import get_braille_chars
from generate_char_palette import *

# %%
ASCII_SET = get_asciis()
BRAILLE_SET = get_braille_chars()
ASCII_WITH_INVERSIONS_SET = get_char_set_with_inversions(ASCII_SET)
ASCII_GRAYSCALE_SET = get_ansi_256_colors_grayscale_set(ASCII_SET, 4)
CHAR_SET = ASCII_SET

colorize_settings = AnsiColorizer(True, True, 1.1, 0.5, False)

# %%
FONT = ImageFont.truetype("fonts/CascadiaMono.ttf", 12)
IMG_PATH = "imgs/rgb_grad.png"

# %%
orig_img = Image.open(IMG_PATH).convert("RGB")
#orig_img = ImageOps.invert(orig_img)

print(orig_img.size)
# Out:
# (512, 512)

# %%
def i_preprocess_img(scale_factor, contrast, brightness, sharpness, enhance_edges, quantize_colors, eq, dither, grayscale):
    proc_img = preprocess_img(orig_img, scale_factor, contrast, brightness, eq, quantize_colors, dither, sharpness, enhance_edges, grayscale)
    plt.imshow(proc_img, cmap='gray', vmin=0, vmax=255, interpolation='none')

    plt.figure(figsize=(9, 3))
    plt.xticks([x for x in range(0, len(proc_img.histogram()), 25)])
    plt.bar([x for x in range(0, len(proc_img.histogram()))], proc_img.histogram())
    plt.grid()
    plt.show()

    return proc_img

interactive_preprocess = interactive(i_preprocess_img,
            scale_factor=(0.01, 1, 0.01),
            contrast=(0, 2, 0.01),
            brightness=(0, 2, 0.01),
            sharpness=(0, 2, 0.01),
            eq=(0, 1, 0.01),
            enhance_edges=(0, 1, 0.01),
            quantize_colors=(1, 256, 1),
            dither=DITHER_MODES,
            grayscale=True)

controls = VBox(interactive_preprocess.children[:-1])
display(HBox((controls, interactive_preprocess.children[-1])))
# Out:
# HBox(children=(VBox(children=(FloatSlider(value=0.5, description='scale_factor', max=1.0, min=0.01, step=0.01)…

# %%
proc_img = interactive_preprocess.result

# %%
palette, palette_br = generate_1_1_palette(ASCII_SET, FONT, 12, normalize=True)
ascii_arr = img2char_arr_1x1(proc_img, palette, palette_br, dither=DITHER_MODES.FS, colorize_settings=colorize_settings)
for i in range(len(ascii_arr)):
    for j in range(len(ascii_arr[i])):
        print(ascii_arr[i][j], sep='', end='')
    print(reset_code(), end='\n')
# Out:
# @@@@@8@NNBBQggR$RRR%RRb%wdPOhOaK32uUuI*3zz*iro\j/T>t[1oJCV132yV7U4ub5PhHEd%RRRRR%QR$Q80WN@8@@@@@@
# @@@#@&@$@g#M$$RR%%%RPK%DDP43OIyfyuy2cZiFFTrJi?{>*?co<){|}*u1VIu7Ua9V]G6O5Ahdb%R%%%N%808W$@Ng@0@@@
# @@@@@#@#$B88Q%&RN%%RRE6bE5GpemSOVU]yVF3{]}rxJ/YL{Ls<vocxtacexffu2aIqwyKOkAmR%R%R%%$&WN88Ng@M@@@@@
# @@@&@g$@B8NBQM%R%R%RE%qGO9DXEXd23V]ai3t{Clx[FxL)>1L)zsc)[x3F]2ye]4uI4GkhKbdPPR%RRR%8RMM0@$@8@0@@@
# @@@@8@$$WQ8$0%M%%R%%hERAK4pymuaXIXfU]TIYvrFv\l+*\z{+*no}cz2Y2J7UUadIE395P6w%%A%%R$R8BNMWM#@&@@Q@@
# @@M@@B@8@Q&&Bg%BRRRRORA4Kk95y4eEU]Vutfi7JCYovj?i<+{s/ljYTurXX2eeX735Z9kuwpD%k%RRRR0Rg8g0N@W@W@@@@
# @@@0@Q@W$NQ08%Q%%%%%PRD4Kb29AfE]aVZuuJ7(*)(t\|<c?1+lszilYlVcYV]yuKZhIwEG6GD%hRRR%%%8Qggg$M@#@#@@@
# @@@@W@NB@$N8$RRW%RR%K4RqhbKym]27aI3]xVY17l|isvL(+c?T{+o[l}7s3I7ue]ywU9kHqmKRP%RR%g%0R80W@&0@$@@@@
# @@@$@8@$$00MMWRR%%R%RkEH4E4GuhZHIU73)fTSll1x<}[/x?{<{vxta}tXa13Uu5fqVAVdEqpRA%R%R%%QMQW##@$@@8@@@
# @@@@@B@$Qg$Qg%8RR%%4R6%54wZbXDuX3fZu71]JjoYn|L*<|?Tt*rTnT[asUI]fIu2KU66pm4mDR%k%RR&RMM&$M&@g@@#@@
# @@@g@M8@&M8$&NRg%R%RqRGw5mDPIwXbf]uyv2ctTssoC/)>C+C\otsFF*uT32I72]67H]m6HPD%5RR%R8R#NNN0g@$$@#@@@
# @@@M@@QQ@&gW0%#%%%%%k9kAqh67GSeI3Uu7a[Zntt|r<{Y+\C>{?jnrn(2lVs32Z]74uh5kOE4%w%%%%R$%8#$##W@Q@@@@@
# @@@@NQ@N&0$0M%0%R%RRRR4GPHPDSOOZeaV2lf)al)lsT/((>c\nFFtCiZzZeUeSf5SAKe4ApKH%5%RR%R%$RgQN@M@N@&@@@
# @@#@@B@g88MN#Q%RRR%%5wRDdhyEby]3AXfft2}s{JzYTJ++YL1F?[1rFFaFre3u]yf75kGDE9H6RR%RRNRBWB8$&B8@Q@@@@
# @@@@Q@&@#0Q80RMRgR%%9%qO9E67OuE22fa72zU)eYFt>Cx<*>{\sr(Tl17JeIeSSb75yEUwkO4RDRKRR%gRg08QW@&@@8@@@
# @@@B@B@N#@B$8R0%RRRRPDKHHpkOe6XI3fX)ajaTi*)ic?z?C+}[}}}({iI|Vef7]]]PfOKddHwRO%%RR%$RQMgNM@&g@@M@@
# @@@@M@&N#MWB#W%%RR%%hREOKmhSAe9yfa]3XTU[ntrFz+[/s?|\rLcT|y|f1V]Xe29Xd3pDEpP6%%R%%RWg%0BN8W@8@N@@@
# @@@Q@$@B@N#&R8R0RR%%G%H4bDDmSmuSmaIy*yYs1tYT+}c/s>i/*(1xv(yjauVIyuSO7Gdmqqd%9%%%%%RQWN$$@$@W@@@@@
# @@@@0@#@&8#QQMR%R%RRDR4GOKk7OZbeZU2ae)2c]nt1o\v/>x+*o*{cna|7FUU]fG3kGfGPPd5%w%%%R&%&RQQ&MB@8@B@@@
# @@0@@N@M&M&0M%W%R%R%O%wEwEpAUwZffIa1][fco|cJ[cLz\([/s()Yjvy[Ufuaa3X7dbH]hA4ARA%%R%R#Qg$M@0Q@&@@@@
# @@@@&@B0gNN$B%M%8%RR5O%K5mIGX97ZyVZuaY7TJlTT?t<t\Y/{z/C|*CalVY27IuDZp7wddKRb%%RR%%0Rg&B#M@#@@#@@@
# @@@N@&@B@WgM$0%RR%R%A%Gm5hKAa5Xm27VytUsCU}o1i+c<c/1>t)cC7v3i3uIeSX62HdOEKHH%H%R%R%&gRg8N$N@g@@0@@
# @@@@&@$WWM&BR0R8R%%RhRk6OOpSwS]SSeau][V[**(c)F+z\|/cCsoj1*s3c3]y33ImaUDwpdkPRH%RRRRBN&#8@$0@M@@@@
# @@@M@0@$@Q#B#$%%RR%RpHRDAPAO7KabeI7yCyoT}(v<1L|<)<n/[ojl{Ujay7SIuhZdDEGEpA6%ERR%%g%Q%80Q$0@&@M@@@
# @@@@W@$&$&##&%8%R%R%wRhbk9VbA3GffVeI7i3lVlns}CLsL|LoYY{lFs7(VFIfV77X6u4U95hRD%%%%%#R&g$NQ@g@M@@@@
# @@W@@M@B@gQW&QR#%%RRH%hGDGpfHf2aSV7ylXlnjj(*?TTsc/Yn\JroxrIJUZeUZDUpUE5Gw64%w%R%R%R&$NM#Ng@B@@N@@
# @@@@W@$g8#BWRWR%%%%RKh%9pqPwV9ypUay]*VZJjox)Fnv>)jl[rt1j{jX(f]aXX7X9SPhG6HP%hR%%%R0WRg88@08@N@@@@
# @@@#@B@&@WB$#$%Q%RR%%bH666eAKSKuVI7VST[]To)o[YoJ()Y1}{zTCfJ]vu2f3ywu6VqhqE5R4%R%%%%M$8W0M@M@B@g@@
# @@@@&@0gB#BB0RQ%%%RD%PROPO92wXuZ7y2V*]1F3*aiTfvf)X}|unlU{TecuafySZuh2HDEdb4kR%A%%WRB%8B#Bg@B@@@@@
# @@@W@B@B@g0B$%0R%%%RE%mhqD4k]634SXSuV{SI)yY7salasytUY7C3[2rZtV2ZyO3w9e9hEHwRm%R%RR#%8#Qg@Bg@N@g@@
# @@@@#@B@Q#BBQ#R%RRRRm445qOqa4eEuVyUayZaaZ3XZZ3X]2]Zfa7ya23aIZe1UZ]fudOSwqOE%PRR%RR$gBgB&&@M@&@@@@
# @@N@@#@$Q#N$%MR&%RRR%6%HdHkVPufZfVZVSZVSI2IUfIfVyZXyX2VVVy2Uu2ZaywIhVKAE6GHm%%RRR%R0%gQ0&&@g@@8@@
# @@@@$@8BWN$#8&%RR%%R9RbAOmdPak35I53yVI7af]Ze77ufI3ZVyXe3UeV2ZI6Xf7kShaP6GwA%HRb%R#R$#Qg0@0#@0@@@@
# @@@0@8@0@NN00%&RW%R%bk%9pAakPIDVwa4UDPV5O2wOZwpSOmIOK3b4SdmSkubS4uOIwpD5AkER5RR%%RNRQ8BM&@8@@g@@@
# @@@@$@MQ&$NB8&RRRR%%p%kG6hwymG99Zwd4eq4U6bZhKZO9abEu46X9A]AmqkqwhwZGV43wqmdkR%%R%RNRg0#WB8@8@@g@@
# @@@N@0@g@B$8&Rg%RR%RKRk9GDK6K5XmqkKhG564HK4Dm46kwm5p6mdp4qG6EIA4ZOAGpw5EwPwRORR%%R8B%&$NW@#0@8@@@
# @@@@B@###MW8M%N%R%%Rp6OEKwGkKqwOmbPObhdKwq46Kq5DpOK56d5dDqw5bwwbGODw9PADm59%ARR%%%RWQ$&NgB@#@@@@@
# @@W@@g@$@Qg0g&RW%%%%%%dRqRE%ARkRmRAq%bpR4b%GRpRw%9%qRdRERA%E%9%4RRARHRORk%b%ARR%%N%8RQWg@#@M@&@@@
# @@@@$@Q$W&M0%0R%R%RD%RRR%%%d%%R%R%R%%%R%%RR%ERRR4RRRkRR%PRR%d%R%9RRRR%RR%%%%%H%RRR%$8#&Q8g@M@@W@@
# @@@g@&@M@gQN#0%g%%R%%R%RR%%%%R%%RR%%%RR%RR%%RR%%%RR%R%%%%%%%RR%R%%%%%%R%%R%%RRR%R%0%0&QWM@W@&@@@@
# @@@@#@W&88gQWR#%R0R%R%%R%RR%%RRRR%%R%%RR%RRR%R%R%%R%RR%%%RR%R%%RR%R%RR%RRR%R%RR%BRWQ%M8Bg0@W@0@@@
# @@@M@M@M@#M0&RggM%Q&QNNMBQQMg$BgWRM&BR$#g%$QMQNW#&#NgN#M$M8&8MW&&W&W8#MRM&M$NB0$RWR#M#Mg@gg@8@@@@
# @@@@Q@#@8NN#g0W$$QN$&$g#RW$NBN&MgNg$$#$QMQBQ8gM&M00gB&g8BN00$&N8#WMQWWgBQNB8#Q0gQ#QQBW#NB@B@@$@@@
# @@8@@&@&Q#Wg$MQ$QM&Q8W$0QQQ#WMQNQg$MgMQ&#Q$B0M0B#8&MgB#NM8M0W$BW#M8$$$$#0W$M00#B8&ggg#gQ&N@N@@#@@
# @@@@$@&#@N@g@&@B@$@0@#@#@$@#@$@$@B@N@Q@g@g@0@g@8@8@Q@W@Q@B@&@#@8@N@&@$@8@0@gB@#@g@B@N@Q@@&8@g@@@@
# @@@0@0@@M@#@B@Q@Q@N@N@8@g@#@W@&@N@B@#@Q@#@$@&@B@g@$@Q@8@B@$@M@0@g@N@B@M@B@g@@8@&@Q@M@0@8@g@$@#@@@
# @@@@@@&@@@@@@@@@@@@@@@@@@@@@@Q@@@@@@@@@@@@@@@@@8@@@g@@@B@@@@@&@@@@@B@@@@@8@@0@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@0@@@@@Q@@@N@@@B@@@@@@@@$@@@$@@@N@@@8@@@@@@@@@@@@@N@@@@@0@@@@@$@@@@@@@@#@@@@M@@@0@@@@Q@@

# %%
palette, palette_br = generate_1_2_palette(CHAR_SET, FONT, (8,8), normalize=True)
ascii_arr = img2char_arr_1x2(proc_img, palette, palette_br, dither=DITHER_MODES.FS, colorize_settings=colorize_settings)
for i in range(len(ascii_arr)):
    for j in range(len(ascii_arr[i])):
        print(ascii_arr[i][j], sep='', end='')
    print(reset_code(), end='\n')
# Out:
# @@@@@@@@@@@$@$$$$N$NNN$#BB8RODGKAdO5]]53X2U1tU3)tCU1II1134h5]GHOGDKA8D0##NN$NN$$$$$@$@@@@@@@@@@@@
# @@@@@@@@@$@$@$@$$$$$$$$RN88RB#B8B4A6E4554]5t32C1)3)II4hhEh445648RBBB0BR#8RN$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$$$$$$$$$$$##0#B08B8#PO9DE5E544hE(XCI)IZhXE4E45hhB]#4BR00RR#NR$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$@$$$$$$$$M$8RB#0RRH0]DEE4E5]hIhVtlI(1l]]Ehh55]hD9bRRBRR8B08$$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$NRR8##00B9A#]E5]h54hh2lI|U)22V44]45454#50P0#R0088M$M$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$8M$#080RR0h8h65h4EEEV]X(X{VCI5Vh4hEhEED9K#0R0R#RBN0$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$$$$$$$$$8N0BR#0RB#E0h]444EE55ZIt|2(IU544]]E]EER50DBB#BBRRR$$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$#00088##08]8EGhhEh4hh2lIY3(U|X54hh]5]4AP%88R8R8B0RM$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$M$B88#BR##E8]h5E5hE]1]3|VYZXtE2hh]h5]]0hR90R80##R$$$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$@$$$$$$$$$$0R8#0R#RBhB4D54EE55h2VI}SlUC5544h]4h5K9b8#88BRRR#B$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$$@$$$$$$$8MRR#RRR8#h8E4]55h5hhS)X(t}XU3]5]455]]0h#hB8##8RRMN$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$RN#0BB0B##ER]G5E5]h]U5X[IY3[Z41E]]]4]ED96#B8B#R8#$8$$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$##8R8##8BB5Rh45]h]hhEVVt}3YU[h45h]h]E50]8980#8R##B$$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$$$$$$$$$M$RBRR#8#R5#4K455]45ES(tY3C1II54454EEEd9OBB0R#808RMN$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$$8BBBB#R#RE8E5]]4E4EUEI}IlZ)V5Zh]E5]4]R]0AB#R8#88NN$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$#MN800800Rh05A54EhE4522t(X(3Ih4444]5hEG9A008B0#8B00$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$@$$$$$$$$$BNBR8R#RR#584EE]Eh4hhZ(2|S{IC2]]4hh]hh84BP0R##8B0M$$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$$@$$$$$$$B8##0B008#]8hbhh4h]hZ4U}t)ZSUhI54h5]5]bPDR08R08RRNR$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$M$R00B0000h84455E45E5S2tl2|U|hhE4Eh44]B58h08R8#0#B$$$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$N#8BBR##8#4#]6h554]5]t{I|2{3XUhhh5E4EE69d8BRB#B#RRM$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$$$$$$$$$#M88B##8BBE85]]45hEEU4UYZ{1CX425h]545h0E#P0##88BB$N$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$0N#00#RB0Rh0]AE4]]EhhI3U)3[V[4]h5]E444b9O88#BRRB#R0$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$R#0###8BB#hB5]]]h5]5]S)I|Z(S3154h44E5]#]BG0#880RRMN$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$@$$$$$$$$$MN0RBB#BRB4BED4h4]E4141(1)1|t]I5E54E4EAPbB8RBB#BR$R$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$$@$$$$$$$$R08#RBB0RE0]]E4Ehh5E12t)tl1I5]EE5]E558hBPBBBBRR##$$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$BM$8#RBBR#E#5H444]45EZ)IVt33(V5E4]h45]KPGBRR#R00RRMN$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$8N#RR0BB##4R4hhEh4E53E415SEXE2E]]4h545B]0]#R#R0R#$$$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$$$$$$$$$8R0888BRBB]85G]]E]4hE]5E5445E5E5E45hE4GPAB0##R80008$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$M$8R0B8##8hBhE54EE]4h45]]45]h4554E]5]404RP8RBB8#RM$$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$$##R##B08R]#46E544]E5]5]E5]E5h55hh555EA9H0##8#BB8$B$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$@$$$$$$$$$8M8BB8#B#8]R5D5Kd5D]65O5HE%]dh%5OAhAH4B]8A00BR0R0B$$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$$@$$$$$$$0$BB8B0B#Bh#E0D9%0%#5BH04R6B5#DBh#O9H0hR48R#0BRBR0M$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$RB80#00R808RR#R0B808BB##RB8B##BR088B088R0R#08B88RNN$$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$MN08R0BRRBBRB0B0B#00#8B888#BRBR8#BR#80B888R#B#R8BBR$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$$$$$$$$$NRR8R###B#080B0#B#0RRRRB##B#B#00RB0B#0B#BR8#R#0R8MN$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$8M$8BB0RRBB##R088##08R0#008#BB0R0BR0##R#8#R0#0B0BNR$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$0$R$BN8$8N#$8$BNRN#N#$RN#N#NRN#$#$#$BNRN#$B$0$8N8N0$$$$$$$$$$@$@$@@@@@@@@@
# @@@@@@@@@@$@$@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@$@$@@@@@@@@@@@
# @@@@@@@@$@@$@$$@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@$@$@$@@@@@@@@
# @@@@@@@@@$@$@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@$@@@@@@@@@@@
# @@@@@@@@@@@$@$@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@$@$@$@@@@@@@@@@
# @@@@@@@@$@$@$$$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$$@$@$@$@@@@@@@@@
# @@@@@@@@@@@$@@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@$@@$@$@$@@@@@@@@@@@
# @@@@@@@@@$@@$@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@$@@@@@@$@$@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
