# %%
import sys
sys.path.append('../../../../src')
sys.path.append('../../../..')

import os
from PIL import ImageFont
import matplotlib.pyplot as plt
import numpy as np
from palette.symbol2value import get_asciis
from converters.line_heuristics.greedy import GreedyLineSearch
from converters.tile.bin_1d import make_1d_bin_palette
from image.processing import DITHER_MODES

from tests.experimental.test_loop import Params, test_loop

FONT_PATH = "../../../../fonts/FiraCode-Regular.ttf"
FONT_SIZE = 10
FONT = ImageFont.truetype(FONT_PATH, FONT_SIZE)
ALL_SYMBOLS = get_asciis()
SYMBOLS = [s[len(s) // 2] for s in make_1d_bin_palette(ALL_SYMBOLS, FONT, 9)[0]]
MAX_WIDTH = 30
MAX_HEIGHT = 9
IMG_SET_PATH = "../../../../imgs/BSDS500"
IMG_PATHS = [os.path.join(IMG_SET_PATH, img_name)
             for img_name in os.listdir(IMG_SET_PATH)[:10]]

def make_converter(params: Params):
    return GreedyLineSearch(
        symbols=SYMBOLS,
        font=ImageFont.truetype(params.font_path, params.font_size),
        **params.converter_args)

# %%
# edge enhancement

edge_enhancement_vals = [
    e for e in np.linspace(0.0, 2.0, 5, endpoint=True)
]

params_space = list(
    map(lambda e: Params(
        max_width=MAX_WIDTH,
        max_height=MAX_HEIGHT,
        font_path=FONT_PATH,
        font_size=FONT_SIZE,
        converter_args={},
        preprocess_args={'quantize_colors': 2,
                         'dither': DITHER_MODES.FS,
                         'enhance_edges': e}),
        edge_enhancement_vals))

similarity_scores = test_loop(IMG_PATHS, make_converter, params_space)

plt.boxplot(similarity_scores,
            labels=[e for e in edge_enhancement_vals])
plt.show()
# Out:
# Min: -0.0032 | Max: 0.0665 | Mean: 0.0365 | Std: 0.0248
# Min: -0.0033 | Max: 0.0612 | Mean: 0.0346 | Std: 0.0231
# Min: -0.0033 | Max: 0.0608 | Mean: 0.0318 | Std: 0.0229
# Min: -0.0033 | Max: 0.0589 | Mean: 0.0312 | Std: 0.0214
# Min: -0.0034 | Max: 0.0594 | Mean: 0.0302 | Std: 0.0220
# C:\Users\wojte\AppData\Local\Temp\ipykernel_9096\2815104393.py:21: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(similarity_scores,

# %%
from PIL import Image
from image.processing import preprocess_img
from rendering.terminal import print_gallery


converter = GreedyLineSearch(symbols=SYMBOLS,
                             font=FONT)

results = []
for img_path in IMG_PATHS[:5]:
    img = Image.open(img_path).convert("L")
    img = preprocess_img(img,
                         enhance_edges=0.4,
                         find_edges=0.8,
                         quantize_colors=2, dither=DITHER_MODES.FS)
    font_height_px = FONT_SIZE * 1.333
    font_width_px = FONT_SIZE * 0.5
    scale_h = MAX_HEIGHT * font_height_px / img.height
    scale_w = MAX_WIDTH * font_width_px / img.width
    img = preprocess_img(img, scale_factor=min(scale_h, scale_w))
    results.append(converter.process_image(img))

print_gallery(results, 2)
# Out:
# ---------------------------------------------------------------------
#  | D/DEDEDDD/DEDEDEDEDEDEDyDED/D/ | DDDENDNNNNNDDNNENDDDEEDDDDDyNy |
#  | D/D`LL`DDyEEDEE``yDyEED/y-`Ly- | DDDEDDNNNNDNDDDDDDDEDDDDDEDDDE |
#  | D/DEDEDEDEDEDEDEDEDEDEDEDEDEDD | DDDEDDNNNNNDDDDDDEDDDy/DEDEEDE |
#  | DEDEDDDEDEDEDEDEDDDEDEDEDEDDDD | DDDEDDNDNEDDNDD/DDDED/DED/DEDy |
#  | DDDEDDDDD/DyEDNEDDDDDEDDDEDEDE | DED/DENDNNNyDEDDDDDDDEDEDyDDDE |
#  | DDDDDDEDENNyDDDDNDNDNNNDNNNEDE | DyDEDyNDNNNDDEDEDEDDDDDEDDDEDE |
#  | DEDDDDDDDDDDDNNEDDNDNDNyDNNyDE | NDNyDENDNNNDEDDyDDDEDDDDDDDDDD |
#  | DNDDNDNNNNNNNNNNNNNDNNNDDDNEDE | DNNDNDNNNNNNDyDEDDNEDDDDNDDDNE |
#  | NDNDDDNDDEDDDEDDDEDNDDDEDEDEDE | NDNDNDNNNNNNDDDyDDDDDEDNDNNNDE |
# ---------------------------------------------------------------------
#  | DDDDDDDED/DEDDDyDDDEDDDEDDD/D` | ```````````````` |
#  | EL/ED`D/D/DyDEDEDyDEDED/yL`ED/ | ```````````````` |
#  | DyD/EDD/EEyED/EyyED/EL`L`LD`yy | `L`L/L`L`L`L`L`L |
#  | DEEEDDDDDDNDNNDDNDNyEDNDDNDNDE | `L`L/L`L/L/L`L`L |
#  | DDDDNDNNDNDDDDDDNEDDDNDDD`DDNE | `L`L`yDyyDE``L`L |
#  | DDDDDDDyEEDDDDDDDDDDDENDDEDE`` | `L/L/DDDDDNy/L`L |
#  | DEDDDDDEDDDDDDDED^DDDDEDDEDEDy | DED/`DDEDEDE`L`L |
#  | DDDDDENEDDDDDEDDDDDDDEDENDDDDE | Dy/DDDDDEEDDEED/ |
#  | DDNDDEDDDDDDDDNDDDDNNDNDDDDDNE | yEDDDDDEDyDDEED/ |
# ---------------------------------------------------------------------
#  | DENDDDNEDEDEDEDEDDDEDNDDDENDND |
#  | NyNEDEDDDDNDDDDDNDDEDDNDNDDNNE |
#  | NDNEDDDEDDDDDDNDDNNDDDDNNyNDNN |
#  | NNDENDNDDNDEDEDDNDDNNDDDDEDDNE |
#  | NDNNNDNDDDDEDEDDDDNDDDDEDEDE`D |
#  | NDNDDNNDNDNEDDDEDNDED/D^`ED``` |
#  | NNNDNDNNNDDNyyNDDED``DNyyEDLyE |
#  | DDDDDEDNNDDDNDDEDEDELyDyDDDDDE |
#  | DDDDDNNNDDNEDDNDDNDNDDNEDDDEDE |
# ---------------------------------------------------------------------
