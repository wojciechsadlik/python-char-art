# %%
from PIL import Image, ImageOps, ImageFont
import matplotlib.pyplot as plt
from modules.img_processing import DITHER_MODES
from modules.palette_generator import get_asciis, make_1d_bin_palette, make_2d_bin_palette, add_ansi_256_colors_grayscale
from modules.print_gallery import print_gallery
from modules.img2chars_mono_1d import img2char_arr_1d
from modules.img2chars_mono_2d import img2char_arr_2d

# %%
ASCII_SET = add_ansi_256_colors_grayscale(get_asciis(), 4)
FONT = ImageFont.truetype("../fonts/CascadiaMono.ttf", 11)
IMG_PATH = "../imgs/irad_grad.bmp"
IMG_SIZE = (32, 32)

# %%
img = Image.open(IMG_PATH).convert("L")
img.thumbnail(IMG_SIZE)

# %%
plt.imshow(img, cmap='gray', vmin=0, vmax=255, interpolation='none')

# %%
bins = 64
palette, palette_brs = make_1d_bin_palette(
    symbols=ASCII_SET,
    font=FONT,
    bins=bins,
    normalize=True)

results = []
results.append(img2char_arr_1d(
    img=img,
    bin_palette=palette,
    bin_vals=palette_brs))

print_gallery(results, 1)
# Out:
# --------------------------------------
#  | YNC6$bPPr/- ^;*>"='- ,"3XmbnL}N< |
#  | }6uqMY_ `JbN(s3X4C])$Ef'-,s$UB4[ |
#  | QbM]-^iQ}ZD@@WO&HHQ@N#X}\o':)Dq$ |
#  | ph+_zMIANGes#Zf"(IeHtS0ME[D]'-29 |
#  | P,:9cbB%e%J..:~l"!:.^im2mN6{9~;1 |
#  | +`X@ABd}I;'rqNR#80Bqc.;x84Mp}p_` |
#  |  +=VMgtF'~RNp$%b|H2mB8~ ozdWec(. |
#  |  ]TwQ9g-:sMHnuBzi\?#4NZ-,4CBE@V^ |
#  | .!cdR7c=-f$HC=?]/q2JABV_`Ah@mo3. |
#  | ./%V$kzn "8B6a}|hKDUgRx l&5QkxL  |
#  | !:drdN6Ml,_zmM#dGRNBn; T#V@d}u.` |
#  | m;`h}HQ8om~' !^l??"-,<XtKMPfp<^I |
#  | KD_;YQCwN8C)?<lc?nPTxV%Wg4z|_;em |
#  | ]k0Z,.t$75R$R%mUkG#$W#d{cZ!.?h4u |
#  | z5Bqg(-:>"<lx7hXVeFjl&f-;'T5GZD* |
#  | /%jmJ4P9v'- :*:<"\!.  ^{5$4u)kTI |
# --------------------------------------

# %%
bins = 64
palette, palette_brs = make_1d_bin_palette(
    symbols=ASCII_SET,
    font=FONT,
    bins=bins,
    normalize=True)

results = []
results.append(img2char_arr_1d(
    img=img,
    bin_palette=palette,
    bin_vals=palette_brs,
    dither=DITHER_MODES.NONE))

results.append(img2char_arr_1d(
    img=img,
    bin_palette=palette,
    bin_vals=palette_brs,
    dither=DITHER_MODES.BAYER))

results.append(img2char_arr_1d(
    img=img,
    bin_palette=palette,
    bin_vals=palette_brs,
    dither=DITHER_MODES.JJN))

print_gallery(results, 3)
# Out:
# ------------------------------------------------------------------------------------------------------------
#  | =*x4BUPU7/' :,,:"\+:.:<TK%A$djB1 | xErPzAp58`,;.:!'___- :*=RWVupeR^ | ?~]bI4m#W?^ _^/*_`>` ,?[XdAnKjE1 |
#  | sb[q&Q_ +^K%c3ySe}7xBPL'^-[Dqn6f | FlIA&T: :;+g)u3V2]}(|ZZ-''3NbQ8f | sAWk&@=.,s7WY3jZt3CTO|}`_`7&bXvx |
#  | CAM(;:[0ISDNQ@H%08@RQ0Vj?1;^{&5$ | R5R{:<o?ieKMM%Bpgg$WM&Z[+P` }dAM | J4NY-;x8n2DMQWH08%MRMR2}gj<:~Mq[ |
#  | Kq!-FN{9NGuJMXJfLtwQfhH@U}?].-Up | H5*'FOfPND]fmVIYxsbQtVH$DC?|^:6% | O$<-oQtENmZf|A?fIiU*jy8B8yOZ;:0p |
#  | U,.K)HBH]B(^ `"1;!: :[LoG$wtd,:Q | 5:;kiPMwyOL`.!"+;~,_:*R[&B6{d~_Z | 0,:d(bMmI|(^._^Y?!! ^>\{6$%oS\;{ |
#  | *^HrOQ5@l..1w$gR80N8x:`JHARbnq,: | <'bimQdWx^:+qN080NM&c_ f09NwuP,^ | !,XxOM6D"-'?qND0#0BQ?: [v9QH}w,' |
#  |  *%ZM%ii`;dBmhdbL}SGBG! t}ENhrz  | ;F*eBbYv_(]89#fbl42kME~ "D#Wh)=  | ./0hNGnj ~PMOB9kkq2kBHT ]&9Q2x[. |
#  | .}1HQPD,,uBp0IRy7>3oUMo_^AoROvq- |  [@5@pL"`[$do?\a,#uJ4N5.-PyR&Ta; | .1(9Rp2"'aNk[JMn*gn#UMt:;VFW5TV' |
#  | .zLqQ2T;']$6g>Mt<KICqMV..hFBGyH- |  k1mN2Q:,S@Agec=x;ZpGMk!_eegAoJ; |  HvOBo%~:7$m&IBf?O3#qBe`:kFQ8j|: |
#  |  /#k@5zT ;d$9ZGvTd&q8Hv vgkWV1c  |  !)Z$&M( ^PMHe(4bp#kg%| t@p$av?  | ._1aNb([ !8Nqapvvb0b##v n%AQSvC  |
#  | <-3vA$E%L^_i#N8P9DMMF;.[?7Bw[h`: | ?^v{ERbRL _fqNDORRMM1"'<HuM&vO:^ | ~^kW6Np\) _)QMDHm#$Q[".vOo$KoZ_- |
#  | 9,\PjON#FGF: !;|LY~':<StwB9uV\_z | m,=UyGNgnRL-'"|LLx!  ;<(4BPL<,^c | D__djPW%nM~_ !">Y!! ._p2wBpu7,-| |
#  | m0-;~8CpQgVtDyl^v^Z%{u%$D2TT;,K9 | q5/\cis8$%XLL|T,!jZhWu%WOkOA``d@ | GX_;vD30$Oa[Gs"~lt=yj2DNgkvn'-HK |
#  | QqQr;'v8{m8NN&mAkDDWW8H3YA~."d4$ | n5e)^^dO3Z0MNOUKPm8R@Rbo1Y, \g%I | NUg@:_oc{p&MR0dbEgD$M#G])^/./9AF |
#  | oEQ50@-__K0LxIVZha{3@$|_^:)9mXrS | +x7wM[+_+EZlY3[4he[t8B~*.;7Pq@w= | CcC6$7:-,E\Lxyaa44ynzgc*:;J9UZf\ |
#  | ?OxA[k9Xs:^.-,`:'_!' .,lURq]s2?! | ?/i|[bEOz/_.`*<,C~/_._`QP95F&sL: | 'q=)3AO#1=` `\`_>_=' .:TmRUCfFT" |
# ------------------------------------------------------------------------------------------------------------

# %%
bins = 64
palette, palette_brs = make_1d_bin_palette(
    symbols=ASCII_SET,
    font=FONT,
    bins=bins,
    normalize=True)

results = []
results.append(img2char_arr_1d(
    img=img,
    bin_palette=palette,
    bin_vals=palette_brs))

bins = (16, 16)
palette, palette_brs = make_2d_bin_palette(
    symbols=ASCII_SET,
    font=FONT,
    bins=bins,
    normalize=True)

results.append(img2char_arr_2d(img, palette))

print_gallery(results)
# Out:
# -------------------------------------------------------------------------
#  | /9}PFqPPT+,.--+>/_:` _~)bpANHJ;x | vqc4KhQW7>t..,....,,.";Y3RH)HQ,! |
#  | CT3b&r' :;X#@[3hVyFT%ps"^-i0bImr | =E3dSV;.VKGAWXqAedBDbaK?_/VWdrL| |
#  | MU&1`'Im7kRNB@g8m8NQM&Sj?n-`y$5[ | %h9Y}.z+*bbRWQQMMWWQ@64|u4,}79A{ |
#  | K$*-lNtdN&C[Owi1^1K\)hOM6C<];'hd | 8V(,;elE#MV?M|vz=vMTYDM$AYv<,~T% |
#  | %;`6r%@Oe$t. ';>~"- :tlFDQ%fA>^( | W/;}#w%M{Y~^.x-/vuv '9?AMDbVk!LW |
#  | >.UldQqf|:'?bMD&8gBKv_'Y86Nbu9'_ | t-*Ob$4T="!<Agg%6gW3<."]TCDBixj_ |
#  | .`MeQ0}}:"6M%hjc46XwN0! L{EQav!  | +f%iD}Ts:yrMOPS33ZMK&[_.o?]BA{i= |
#  | .ti9@dH,_aMEuIBYFR=&5$2`.<3$mYA^ | .xVR@48L N&9[TF'"<T8O%8:!/[$8RrV |
#  |  LrmQZM*`[$K&3Q[,eC]q$u',AhBP[X; | If/R@(N].{WRJL*-qC}$N9):_UOR0\:X |
#  |  \#aQkj~ ;8BHy8LS9Dbg#\ n>bB2(J  | ^FF$B8@j.^hQ%UUkxs#QNqY VL0B9tL| |
#  | /.a@d@kvt-,|dN0wKR$W{".s>7WEIb`, | Z'[X902c\_ 7@MR#86WMA^;dg[ORh7S_ |
#  | S`*u]U@OI*!:.~~|1<;.`~3WP@Afb,'[ | x iTzP8kX@/-."^"7Y7._,uw%O5zT?^e |
#  | Hk-^)0nKQOhi\7TTz!AGWZ8$021(-'9d | Bi,`C7Y9R&8@J/*,-)9mjhkQ$5II``MQ |
#  | nUR1`-{=Ip&@W#HUb0GBW#Gu)Z\ <9qN | R54o `J715D$&QwkHmW&@R52M7C^ $5) |
#  | n67bNl`,<pDL({4kaaf3lBn!;,zkOVD< | MYNM#j!`YTT5#59955PXP?7]'!eB@5]? |
#  | '#f%$q6BY,, :-\*"-*:  _L4MkMi?"V | :T}5}MWjM\''`'~X;/`'`"{BJK5}89NT |
# -------------------------------------------------------------------------

# %%
bins = (16, 16)
palette, palette_brs = make_2d_bin_palette(
    symbols=ASCII_SET,
    font=FONT,
    bins=bins,
    normalize=True)

results = []
results.append(img2char_arr_2d(img, palette))
results.append(img2char_arr_2d(img, palette, DITHER_MODES.BAYER))
results.append(img2char_arr_2d(img, palette, DITHER_MODES.JJN))

print_gallery(results, 3)
# Out:
# ------------------------------------------------------------------------------------------------------------
#  |  w<qrn%VT?r.,.._,_,..!{QYOnjw06' | f>p[qhkWW`,-.),?-U-J-!QlVKd$mS4n | ~mm)2U57V=.,,,!-[_,.-.tV3%WkXwq4 |
#  | \i8nRT>_*q&a}SUHpqV8Km+2_|Y@bFs> | UOc%Q.V\_J&<L]soqjy3m8xv. Y8Ufx{ | EOEH3-..FxvZ3eKmedAX2dK!x,lT4dR6 |
#  | FbXW^,VK#E6#QWMQMQQM0kw]kf,_VD4D | m%7_Y?+WeHbR&MMCW(QWw%KlxL,ZQBEX | SbT+--XllKO0WMWMMWWQ$BoE6pl,:WBD |
#  | $TF,4EzABQXMB*\9?=YMM4M@HZw:,LYQ | 2s7(rVEOW%WB?Y^!^VB8?ZQOwhy~,!7X | O7^FI$U8RWA?MY==0<BBT5W@#UG|(}TU |
#  | W |SlbNQKMI`;_u-v+L``L?}QRwzd=|Y | Y--?+NQCQ~`'! v(vxa`!<YZWRKZET-. | T(;x/oBW]Lj'!.s-/y .`/CVWDDBm~_< |
#  | ;_ZOdB#B*` a$ggKOWgtx.'9TdR@FYL` | V]:/4WWI?~'FMD&0B%B)/:'EM}M%ZT_} | C~eCDR]Ye".vcgg&B&g{u~`{YSQ0nxj@ |
#  | \[IQ$CTD:/w&9MdXVK5Rg6y.vT30d\3c | !~a9q#Td`?G9gF?T3#5R&Ky:7WMMqX=" | !x8A@(Y9 `mg6M{rVVM9&Uy.*M]$K*). |
#  | >t@B${0x:|BD(T]?3jVtD6%:'=rR@/r3 | ,1vP@SM,!mgNPM[;`9Y85K/;'eU&d/3' | {ZN$N}JX.SUNPHd4YdOMO{5:kX3NDBlC |
#  | 1>*#O30e!lQK6udq~KL8$#c _4(RR*h4 | >x}9$ZK;'GMkRy!-j,?E#M@"h#2wUO2v | _z<NRAc5:(o9dFZsA1)t$JX:HA00@Q;L |
#  | {VVfR(&N!"5MRHVzEz(20)";0@V%9*zI | F\+PNI0-:?]WKnZzVz9WRM<.L1AE4$!` | 'zY90#G3,:DM644IBdU$MZ :Ya6B9@3" |
#  | !':tP@3c<+."(WK%08QQwT:)iX@%n74  |  `25>Q6Q4_.TjM02$w9Ml"'_])$NSP,` | =:(|$$3gj-:"SMWQQWWl7 _]W}RNO?Il |
#  | wC)9r9@MtWP_:T^7Y77:_,UQ(R5[Pr;m | P'_MV5@m6QO;`"`7^T ^~,lxSG69I4<q | JL]?jP84hjr, :?TTY.'-Owad$5YP2;c |
#  | RfZ`/7VP@&#fw\\-~7Ii@rWG$Pnr`|wQ | %f]`SM<PBW6n1aS,b_TorLr&@5i9,'Vo | QaZ[5iB9WQKQJwX=)<pfxXwDDP{P:t}D |
#  | #P9jF`S7}5N@QmwmHEWw#$9D7T>'+QM0 | jPWgv"]9)P$&O&Wy[H@m@kz9]TC']B#P | X$g]'`5FYP%BMWkQwwwQR@55}<+^<i$S |
#  | $TS5$f-`(PT7)5PPPPP}?T7V`~Gs$M@7 | Y9jPRMv`i?97=PS9<9J5TMf5;^]e0MC? | 9]MOA>^^|?P}hP9PPP9QO5M~"`}2DPS7 |
#  | 2TSPfMNfu<'"``J~It^''`:y&dMCR?hP |  T{7f5NzZ'C'^^T"s^z`?`-nQM]P1T1? | 7v9jM5Ni{?""']IILh<'^'C"E6@P[Y\P |
# ------------------------------------------------------------------------------------------------------------
